# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("movies.csv", encoding='latin-1')
data.head()
# Out:
#        budget                                 company country        director  \
# 0   8000000.0           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000.0                      Paramount Pictures     USA     John Hughes
# 2  15000000.0                      Paramount Pictures     USA      Tony Scott
# 3  18500000.0  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000.0                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre        gross                      name rating    released  \
# 0  Adventure   52287414.0               Stand by Me      R  1986-08-22
# 1     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13  1986-06-11
# 2     Action  179800601.0                   Top Gun     PG  1986-05-16
# 3     Action   85160248.0                    Aliens      R  1986-07-18
# 4  Adventure   18564613.0   Flight of the Navigator     PG  1986-08-01
#
#    runtime  score               star   votes         writer  year
# 0       89    8.1        Wil Wheaton  299174   Stephen King  1986
# 1      103    7.8  Matthew Broderick  264740    John Hughes  1986
# 2      110    6.9         Tom Cruise  236909       Jim Cash  1986
# 3      137    8.4   Sigourney Weaver  540152  James Cameron  1986
# 4       90    6.9        Joey Cramer   36636  Mark H. Baker  1986

# %%
#Repress scientific notation
pd.options.display.float_format = '{:.2f}'.format
#pd.reset_option('^display.', silent=True)

# %%
#Data understanding
for column in data.columns:
    print(data[column].value_counts())
# Out:
# 0.00            2182
# 20000000.00      207
# 30000000.00      191
# 25000000.00      177
# 15000000.00      170
# 10000000.00      155
# 40000000.00      150
# 35000000.00      149
# 50000000.00      115
# 5000000.00       113
# 60000000.00      107
# 12000000.00      102
# 6000000.00        90
# 8000000.00        88
# 18000000.00       88
# 13000000.00       76
# 7000000.00        73
# 3000000.00        73
# 45000000.00       72
# 17000000.00       65
# 80000000.00       65
# 70000000.00       65
# 11000000.00       62
# 16000000.00       60
# 14000000.00       58
# 22000000.00       57
# 4000000.00        55
# 75000000.00       54
# 55000000.00       54
# 100000000.00      49
#                 ...
# 260000000.00       1
# 8900000.00         1
# 12800000.00        1
# 10920000.00        1
# 63600000.00        1
# 9200000.00         1
# 65000.00           1
# 126000000.00       1
# 29750000.00        1
# 17700000.00        1
# 176000000.00       1
# 169000.00          1
# 26350000.00        1
# 5600000.00         1
# 230000000.00       1
# 144000000.00       1
# 11800000.00        1
# 950000.00          1
# 2309723.00         1
# 175000.00          1
# 30000.00           1
# 5300000.00         1
# 25500000.00        1
# 8200000.00         1
# 13300000.00        1
# 29000001.00        1
# 128000000.00       1
# 24500000.00        1
# 300000.00          1
# 5800000.00         1
# Name: budget, Length: 351, dtype: int64
# Universal Pictures                                          302
# Warner Bros.                                                294
# Paramount Pictures                                          259
# Twentieth Century Fox Film Corporation                      205
# New Line Cinema                                             172
# Columbia Pictures Corporation                               166
# Touchstone Pictures                                         131
# Columbia Pictures                                           108
# Walt Disney Pictures                                        102
# Metro-Goldwyn-Mayer (MGM)                                   101
# TriStar Pictures                                             85
# Miramax                                                      77
# DreamWorks                                                   76
# Castle Rock Entertainment                                    62
# Fox 2000 Pictures                                            58
# Dimension Films                                              57
# Fox Searchlight Pictures                                     57
# Hollywood Pictures                                           52
# Screen Gems                                                  46
# Lionsgate                                                    44
# Orion Pictures                                               40
# Focus Features                                               38
# Summit Entertainment                                         38
# Morgan Creek Productions                                     37
# Revolution Studios                                           33
# Regency Enterprises                                          33
# The Weinstein Company                                        29
# EuropaCorp                                                   28
# Channel Four Films                                           27
# United Artists                                               27
#                                                            ...
# Lost Soul Productions                                         1
# Two Flints                                                    1
# Hunter/MFG Production                                         1
# Bow and Arrow Entertainment                                   1
# Dash Films                                                    1
# Lawrence Gordon Productions                                   1
# Escalante Productions                                         1
# Thunder Road Pictures                                         1
# Opening Night Productions                                     1
# Shooting Script Films                                         1
# Human Stew Factory                                            1
# Carsey-Werner Company                                         1
# Toy Fight Productions                                         1
# El Mar Pictures                                               1
# Stacey Testro International                                   1
# Mepris Films                                                  1
# Facilitator Films                                             1
# Alfama Films                                                  1
# Ellendale Place                                               1
# Silver Sphere Corporation                                     1
# Arau Films Internacional                                      1
# It's a Laugh Productions                                      1
# Middle Fork Productions                                       1
# Havoc                                                         1
# Solaris                                                       1
# Hammerhead Productions                                        1
# Gray Daisy Films                                              1
# Vinod Chopra Productions                                      1
# Instituto Nacional de Cine y Artes Audiovisuales (INCAA)      1
# Wytwórnia Filmów Dokumentalnych i Fabularnych (WFDiF)         1
# Name: company, Length: 2179, dtype: int64
# USA                               4872
# UK                                 698
# France                             283
# Canada                             150
# Germany                            134
# Australia                           82
# Japan                               68
# Spain                               56
# Italy                               51
# Ireland                             44
# Hong Kong                           39
# India                               39
# Denmark                             33
# China                               24
# South Korea                         20
# New Zealand                         18
# Belgium                             18
# Sweden                              18
# Mexico                              15
# Argentina                           13
# Netherlands                         12
# Iran                                12
# Russia                              10
# South Africa                         9
# Czech Republic                       8
# Norway                               8
# Taiwan                               8
# Hungary                              7
# Brazil                               6
# Austria                              6
# Switzerland                          6
# Romania                              5
# Israel                               5
# Greece                               5
# West Germany                         4
# Chile                                4
# Thailand                             3
# Finland                              3
# Peru                                 2
# Colombia                             2
# Poland                               2
# Portugal                             2
# Indonesia                            2
# Saudi Arabia                         1
# Aruba                                1
# Bahamas                              1
# Palestine                            1
# Panama                               1
# Ukraine                              1
# Republic of Macedonia                1
# Jamaica                              1
# Malta                                1
# Kenya                                1
# Soviet Union                         1
# Iceland                              1
# Federal Republic of Yugoslavia       1
# Cuba                                 1
# Name: country, dtype: int64
# Woody Allen             33
# Clint Eastwood          24
# Steven Spielberg        21
# Steven Soderbergh       21
# Ron Howard              20
# Joel Schumacher         19
# Ridley Scott            19
# Spike Lee               18
# Barry Levinson          18
# Oliver Stone            17
# Stephen Frears          17
# Richard Linklater       17
# Tim Burton              17
# Bruce Beresford         16
# Chris Columbus          15
# Renny Harlin            15
# Rob Reiner              15
# Garry Marshall          15
# Martin Scorsese         15
# Tony Scott              15
# Robert Zemeckis         14
# Dennis Dugan            14
# Pedro Almodóvar         14
# Wes Craven              14
# Roger Donaldson         13
# Gus Van Sant            13
# Robert Rodriguez        13
# Michael Apted           13
# Neil Jordan             13
# Ang Lee                 13
#                         ..
# Dominic Anciano          1
# Niall Johnson            1
# Drew Barrymore           1
# Alfonso Gomez-Rejon      1
# Kirsten Sheridan         1
# Ruben Östlund            1
# Andrei Tarkovsky         1
# Ole Christian Madsen     1
# Hsiao-Hsien Hou          1
# Alice Wu                 1
# Eugene Corr              1
# Gary Hudson              1
# Edward Yang              1
# Susannah Grant           1
# Dominic Orlando          1
# Adam Brooks              1
# David Hare               1
# James Bridges            1
# Jordan Melamed           1
# Nicolas Pesce            1
# Stephen Elliott          1
# Jason Bloom              1
# Nat Faxon                1
# Arthur Penn              1
# Aleksander Bach          1
# Yann Demange             1
# Abbe Wool                1
# Chris Nahon              1
# Douglas Aarniokoski      1
# Robert Longo             1
# Name: director, Length: 2759, dtype: int64
# Comedy       2080
# Drama        1444
# Action       1331
# Crime         522
# Adventure     392
# Biography     359
# Animation     277
# Horror        277
# Mystery        38
# Fantasy        32
# Thriller       18
# Romance        15
# Family         14
# Sci-Fi         13
# Musical         4
# War             2
# Western         2
# Name: genre, dtype: int64
# 20100000.00     3
# 3500000.00      3
# 1200000.00      3
# 700000.00       2
# 1500000.00      2
# 1000000.00      2
# 1000045.00      2
# 50000.00        2
# 119919.00       2
# 69136.00        2
# 19281235.00     2
# 12100000.00     2
# 300000.00       2
# 15324.00        2
# 1100000.00      2
# 85846429.00     1
# 2643689.00      1
# 63270710.00     1
# 38105077.00     1
# 40202379.00     1
# 106954678.00    1
# 396003.00       1
# 135645823.00    1
# 15325127.00     1
# 857522.00       1
# 67823573.00     1
# 1256355.00      1
# 4370078.00      1
# 23247539.00     1
# 109767581.00    1
#                ..
# 349618.00       1
# 32616869.00     1
# 26570463.00     1
# 21848932.00     1
# 19751736.00     1
# 5855392.00      1
# 191164.00       1
# 32589677.00     1
# 72708161.00     1
# 64665672.00     1
# 7690013.00      1
# 2086345.00      1
# 17278980.00     1
# 40069087.00     1
# 613556.00       1
# 551660.00       1
# 1010414.00      1
# 17129000.00     1
# 10400000.00     1
# 72779000.00     1
# 2534351.00      1
# 10137502.00     1
# 79003080.00     1
# 1877179.00      1
# 1168902.00      1
# 68518533.00     1
# 20275446.00     1
# 69117629.00     1
# 57328603.00     1
# 2368.00         1
# Name: gross, Length: 6802, dtype: int64
# Hamlet                                3
# Pulse                                 3
# Promised Land                         2
# The Hitcher                           2
# The Three Musketeers                  2
# Hercules                              2
# Twilight                              2
# Nobody's Fool                         2
# Voraz                                 2
# Death at a Funeral                    2
# Leviathan                             2
# Much Ado About Nothing                2
# It Takes Two                          2
# Anna Karenina                         2
# Jane Eyre                             2
# Running Scared                        2
# The In Crowd                          2
# Project X                             2
# Teenage Mutant Ninja Turtles          2
# The Eye                               2
# The Unborn                            2
# Cocktail                              2
# Black Sheep                           2
# Les Misérables                        2
# Hero                                  2
# Bulletproof                           2
# Out Cold                              2
# The Girl with the Dragon Tattoo       2
# Chocolat                              2
# Concussion                            2
#                                      ..
# The Wedding Singer                    1
# Underworld: Evolution                 1
# Skin Deep                             1
# London Has Fallen                     1
# Modern Girls                          1
# Masquerade                            1
# The Wood                              1
# Dead Snow                             1
# Child's Play 2                        1
# Starship Troopers                     1
# Estrenando Cuerpo                     1
# Flight of the Phoenix                 1
# The King's Speech                     1
# All Dogs Go to Heaven                 1
# The Interpreter                       1
# A Prayer for the Dying                1
# Wish You Were Here                    1
# Hollywood Homicide                    1
# Don Juan DeMarco                      1
# 1969                                  1
# The Haunting in Connecticut           1
# In a Better World                     1
# The Mission                           1
# Click                                 1
# Mr. Deeds                             1
# Sangre caníbal                        1
# Don 2                                 1
# Journey to the Center of the Earth    1
# Delta of Venus                        1
# Gung Ho                               1
# Name: name, Length: 6731, dtype: int64
# R                3392
# PG-13            1995
# PG                951
# NOT RATED         174
# G                 147
# UNRATED            71
# Not specified      63
# NC-17              22
# B                   1
# TV-14               1
# B15                 1
# TV-PG               1
# TV-MA               1
# Name: rating, dtype: int64
# 1991-10-04    10
# 1988-11-18     9
# 2008-09-26     9
# 1988-10-21     9
# 2016-10-21     8
# 2006-10-13     8
# 2007-10-19     8
# 1986-08-22     8
# 2002-10-11     8
# 1993-02-12     8
# 2011-03-18     8
# 2003-11-14     8
# 2008-12-25     8
# 1987-11-06     8
# 2012-04-20     8
# 1989-01-13     8
# 1988-03-04     8
# 1990-03-09     8
# 2000-10-20     8
# 1986-11-07     8
# 1991-05-24     7
# 1987-09-18     7
# 1988-01-15     7
# 2013-08-23     7
# 1988-04-22     7
# 1994-02-04     7
# 1998-11-20     7
# 1992-05-08     7
# 1989-04-28     7
# 2000-01-21     7
#               ..
# 2015-12-17     1
# 2011-03-03     1
# 1990-04-12     1
# 1994-12-28     1
# 2015-08-05     1
# 2015-02-26     1
# 2007-01-22     1
# 2003-09-17     1
# 2014-12-17     1
# 1993-02-11     1
# 2010-05-06     1
# 1999-07        1
# 1986-11        1
# 2013-11-07     1
# 2009-08-01     1
# 2000-06-28     1
# 2000-05-03     1
# 2005-01-13     1
# 2003-11-08     1
# 2008-04-03     1
# 2005-05-19     1
# 2007-04-04     1
# 2003-01-25     1
# 2012-05-17     1
# 2004-09-26     1
# 2006-11-24     1
# 2003-07-11     1
# 2012-09-19     1
# 1999-01-29     1
# 1990-08-01     1
# Name: released, Length: 2403, dtype: int64
# 100    546
# 97     209
# 98     200
# 95     193
# 101    185
# 90     181
# 102    179
# 96     179
# 105    175
# 99     174
# 93     172
# 108    165
# 106    163
# 104    160
# 107    158
# 94     155
# 91     153
# 103    147
# 92     145
# 110    144
# 88     127
# 112    123
# 109    115
# 89     114
# 113    114
# 111    109
# 115    106
# 118    102
# 114    100
# 117     93
#       ...
# 183      2
# 192      2
# 188      2
# 191      2
# 195      2
# 181      2
# 177      2
# 271      1
# 168      1
# 176      1
# 187      1
# 179      1
# 175      1
# 366      1
# 242      1
# 238      1
# 210      1
# 202      1
# 194      1
# 166      1
# 219      1
# 50       1
# 357      1
# 201      1
# 193      1
# 185      1
# 173      1
# 280      1
# 224      1
# 70       1
# Name: runtime, Length: 135, dtype: int64
# 6.70    304
# 6.50    284
# 6.30    284
# 6.40    283
# 6.60    273
# 6.20    270
# 6.80    258
# 6.10    256
# 7.20    244
# 5.90    241
# 7.00    240
# 7.10    233
# 6.90    228
# 7.30    226
# 5.70    221
# 5.80    212
# 6.00    210
# 7.40    180
# 7.60    177
# 5.60    173
# 7.50    169
# 5.50    154
# 5.30    146
# 5.40    140
# 7.70    136
# 7.80    132
# 5.10    100
# 5.20     90
# 5.00     82
# 4.90     80
#        ...
# 8.50     15
# 3.80     14
# 8.40     13
# 3.50     13
# 3.60     13
# 3.70     13
# 8.60     10
# 3.40      7
# 2.90      5
# 2.80      5
# 2.40      5
# 8.70      5
# 3.20      5
# 3.30      5
# 8.80      4
# 2.60      4
# 2.30      4
# 2.70      4
# 8.90      3
# 2.20      3
# 2.00      2
# 3.10      2
# 1.90      2
# 9.30      1
# 3.00      1
# 9.00      1
# 1.50      1
# 1.60      1
# 2.10      1
# 2.50      1
# Name: score, Length: 75, dtype: int64
# Nicolas Cage             42
# Robert De Niro           38
# Denzel Washington        36
# Tom Hanks                35
# Bruce Willis             33
# Johnny Depp              32
# Adam Sandler             27
# Tom Cruise               27
# Ben Stiller              27
# John Cusack              26
# Kevin Costner            26
# Sylvester Stallone       25
# Eddie Murphy             25
# Robin Williams           25
# John Travolta            25
# Steve Martin             24
# Keanu Reeves             24
# Mel Gibson               23
# Mark Wahlberg            23
# Arnold Schwarzenegger    22
# Jim Carrey               22
# Ben Affleck              22
# Brad Pitt                22
# Matt Damon               22
# Matthew McConaughey      22
# George Clooney           22
# Sandra Bullock           21
# Ethan Hawke              21
# Anthony Hopkins          21
# Jeff Bridges             21
#                          ..
# Seung-yeon Lee            1
# Joe Basile                1
# Tommy Wiseau              1
# Yûta Sone                 1
# Ki-duk Kim                1
# Haruhiko Katô             1
# Dave Johns                1
# Eminem                    1
# Tom Welling               1
# Martha Plimpton           1
# Connor Paolo              1
# Rekha                     1
# Georges Du Fresne         1
# Hugh Bigney               1
# Keely Christian           1
# David Johansen            1
# Ian Michael Smith         1
# Campbell Scott            1
# Mike White                1
# Dave Goelz                1
# Michael Jeter             1
# Stéphane Audran           1
# Justine Bateman           1
# Susanna Hoffs             1
# Oksana Akinshina          1
# John Larroquette          1
# Eva Bourne                1
# Jeremy Irvine             1
# Jeffrey Combs             1
# Arsenio Hall              1
# Name: star, Length: 2504, dtype: int64
# 1340      4
# 2003      4
# 1959      3
# 5757      3
# 1943      3
# 9141      3
# 2101      3
# 2385      3
# 5807      3
# 505       3
# 692       3
# 1509      3
# 2180      3
# 13051     3
# 2157      3
# 3075      3
# 11161     2
# 105471    2
# 5354      2
# 2838      2
# 973       2
# 15445     2
# 8970      2
# 5119      2
# 3376      2
# 9152      2
# 44133     2
# 58556     2
# 1410      2
# 19380     2
#          ..
# 23326     1
# 11040     1
# 35620     1
# 23334     1
# 9001      1
# 10992     1
# 21231     1
# 131821    1
# 125648    1
# 64186     1
# 35516     1
# 4799      1
# 160451    1
# 19140     1
# 37575     1
# 8905      1
# 80586     1
# 717       1
# 94931     1
# 8937      1
# 2772      1
# 10968     1
# 58073     1
# 2780      1
# 82653     1
# 39646     1
# 4831      1
# 2788      1
# 213733    1
# 20482     1
# Name: votes, Length: 6512, dtype: int64
# Woody Allen            32
# Luc Besson             25
# Stephen King           22
# John Hughes            18
# William Shakespeare    14
# David Mamet            14
# Pedro Almodóvar        13
# Wes Craven             12
# Tyler Perry            12
# Robert Rodriguez       11
# Joel Coen              11
# John Logan             10
# Lars von Trier         10
# Jim Jarmusch           10
# Michael Crichton       10
# M. Night Shyamalan     10
# Quentin Tarantino      10
# Kevin Smith            10
# Brian Helgeland        10
# Ehren Kruger           10
# John Grisham            9
# Mike Leigh              9
# Steven Knight           9
# Jane Austen             8
# Leigh Whannell          8
# Judd Apatow             8
# John Fusco              8
# Spike Lee               8
# Peter Morgan            8
# Richard Linklater       8
#                        ..
# Kurt Johnstad           1
# Kent Stowell            1
# Justin Kerrigan         1
# Meg Rosoff              1
# Al Franken              1
# David Beaird            1
# Menahem Golan           1
# Virginia C. Andrews     1
# Ed Turner               1
# Andrea Di Stefano       1
# Kent Harper             1
# Chris Denk              1
# Don Ferrarone           1
# David Griffiths         1
# R.J. Robertson          1
# Bobby Smith Jr.         1
# Peter Markle            1
# John Michael Hayes      1
# Lewis Abernathy         1
# Rex McGee               1
# Mauricio Kartun         1
# Carrie Fisher           1
# Andy Cochran            1
# Domonic Muir            1
# Lynn Siefert            1
# Milena Agus             1
# Louis Sachar            1
# Fay Weldon              1
# Jeff Feuerzeig          1
# Damon Lindelof          1
# Name: writer, Length: 4199, dtype: int64
# 1989    221
# 2015    220
# 2013    220
# 1992    220
# 1996    220
# 2000    220
# 2004    220
# 2008    220
# 2012    220
# 2016    220
# 1993    220
# 1997    220
# 2001    220
# 2005    220
# 2009    220
# 1986    220
# 2011    220
# 1990    220
# 1994    220
# 1998    220
# 2002    220
# 2006    220
# 2010    220
# 2014    220
# 1991    220
# 1995    220
# 1999    220
# 2003    220
# 2007    220
# 1988    220
# 1987    219
# Name: year, dtype: int64

# %% [markdown]
# # Prepearing the dataset for processing

# %%
#Get the names of movies with no budget and format the string for a URL
noBudgetMovies = data[data["budget"]==0][["year","name"]]
noBudgetMovies["name"] = noBudgetMovies["name"].str.replace(" ","_")
noBudgetMovies.head()
# Out:
#     year                    name
# 25  1986           Short_Circuit
# 26  1986    The_Name_of_the_Rose
# 27  1986              Iron_Eagle
# 32  1986              Betty_Blue
# 35  1986  The_Karate_Kid_Part_II

# %% [markdown]
# ### Requesting the missing budget values from Wikipedia API

# %%
from bs4 import BeautifulSoup
import requests

def getPage(movieName):
    S = requests.Session()
    URL = "https://en.wikipedia.org/w/api.php"
    PARAMS = {
        "action": "parse",
        "page": movieName,
        "format": "json"
    }
    R = S.get(url=URL, params=PARAMS)
    DATA = R.json()
    return DATA

#Getting the budget value
def getBudget(DATA):
    try:
        soup = BeautifulSoup("<html>"+str(DATA["parse"]["text"]["*"])+"</html>",features="html.parser")
    except:
        return "parseError"
    table = soup.find("table",class_="infobox vevent")

    try:
        thList = table.find_all("th")
        tdList = table.find_all("td")
    except:
        return "redirect"

    budgetIndex = -1
    i=0
    for row in thList:
        if "Budget" in str(row):
            budgetIndex = i
            break
        i += 1

    if budgetIndex == -1:
        return "noBudget"
    
    budget = tdList[budgetIndex].contents
    
    try:
        if len(budget)==1 or len(budget)==2 and "reference" in budget[1]["class"]:
            return tdList[budgetIndex].contents[0]
    except:
        pass
    return budget

# %%
#Sends GET requests to wikipedia API to get the missing budget values
#Takes a long time ~35min
dict = {}

for movieName in noBudgetMovies["name"]:
    pageData = getPage(movieName)
    budget = getBudget(pageData)
    
    if budget=="redirect":
        name = movieName+"_(film)"
        pageData = getPage(name)
        budget = getBudget(pageData)
        if budget=="redirect":
            year = noBudgetMovies[noBudgetMovies["name"]==movieName]["year"].values[0]
            name = movieName+"_("+str(year)+"_film)"
            pageData = getPage(name)
            budget = getBudget(pageData)
            if budget=="redirect":
                dict[movieName] = "redirect. last tried name: "+name
                continue
    if budget=="noBudget":
        dict[movieName] = "noBudget"
        continue
    if budget=="parseError":
        dict[movieName] = "parseError"
        continue
    dict[movieName] = budget
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-937ee2a6a63a> in <module>
#       9     if budget=="redirect":
#      10         name = movieName+"_(film)"
# ---> 11         pageData = getPage(name)
#      12         budget = getBudget(pageData)
#      13         if budget=="redirect":
#
# <ipython-input-6-fa20d960d70d> in getPage(movieName)
#      10         "format": "json"
#      11     }
# ---> 12     R = S.get(url=URL, params=PARAMS)
#      13     DATA = R.json()
#      14     return DATA
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     488         """
#     489         if self.chunked and self.supports_chunked_reads():
# --> 490             for line in self.read_chunked(amt, decode_content=decode_content):
#     491                 yield line
#     492         else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     664
#     665             while True:
# --> 666                 self._update_chunk_length()
#     667                 if self.chunk_left == 0:
#     668                     break
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     596         if self.chunk_left is not None:
#     597             return
# --> 598         line = self._fp.fp.readline()
#     599         line = line.split(b';', 1)[0]
#     600         try:
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
#DO NOT RUN AGAIN IF YOU ALREADY HAVE RESULTS IN A FILE OR MAKE A BACKUP FIRST, BECAUSE API REQUESTS TAKE A LONG TIME TO GET!!!
#Writing dict to file for further processing. 
with open("wikiResults.txt","w",encoding="utf-8") as file:
    for key, value in dict.items():
        file.write(key+"==="+str(value).replace("\n"," ")+"\n")

# %% [markdown]
# ### Take the budget values and parse them into floats

# %%
#Read the results from the file onto a new dictionary
dictFile = {}
with open("wikiResults.txt","r",encoding="utf-8") as file:
    lines = file.readlines()
for line in lines:
    if line=="":
        continue
    split = line.split("===")
    dictFile[split[0]] = split[1].replace("\n","")

# %%
def findNumericDigits(string):
    index = 0
    i =0
    for char in string:
        if char.isnumeric():
            index = i
            break
        i += 1
    return index

def parseBudgetValue(budget):
    currencies = {
        "£": 1.33,
        "€": 1.11,
        "AU$": 0.688
    }
    
    try:
        if "sup" in budget:
            return budget
        if "million" in budget or "Million" in budget:
            row = budget.split(" ")
            firstNr = findNumericDigits(row[0])
            value = budget[:firstNr]+str(float(row[0][firstNr:])*1000000)
        elif ","in budget:
            value = budget.replace(",","")
        else:
            value = budget

        if value[0] == "$":
            return float(value[1:])
        elif value[:3] == "US$":
            return float(value[3:])
        elif value[0] == "£":
            return float(value[1:])*currencies["£"]
        elif value[0] == "€":
            return float(value[1:])*currencies["€"]
        elif value[:3] == "AU$":
            return float(value[3:])*currencies["AU$"]
        elif value[:2] == "A$":
            return float(value[2:])*currencies["AU$"]
        else:
            return budget
    except:
        return budget

# %%
#Parse the value into a float
for key, value in dictFile.items():
    dictFile[key] = parseBudgetValue(value)

# %%
#Manual fixing of remaining errors
errors = ["noBudget","parseError","redirect"]
moviesWithErrors = []
for key, value in dictFile.items():
    if type(value)!= float and value not in errors:
        moviesWithErrors.append(key)
        print(key,value)
        budget = input("Enter new budget value: ")
        if budget == "":
            continue
        dictFile[key] = budget
# Out:
# Summer redirect. last tried name: Summer_(1986_film)
# Enter new budget value:
# Link Unknown
# Enter new budget value:
# Kangaroo redirect. last tried name: Kangaroo_(1986_film)
# Enter new budget value:
# Wings_of_Desire ['5 million ', <a href="/wiki/Deutsche_Mark" title="Deutsche Mark">DM</a>, <sup class="reference" id="cite_ref-FOOTNOTELüdiLüdi200060_3-0"><a href="#cite_note-FOOTNOTELüdiLüdi200060-3">[3]</a></sup>]
# Enter new budget value: 5 million Deutsche_Mark
# Who's_That_Girl $17–20 million ($37.49 million in 2018)
# Enter new budget value: $18.5 million
# Wanted:_Dead_or_Alive $4,500,000 (US)
# Enter new budget value: $4,500,000
# Wisdom ['$6.5 million', <sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>, <sup class="reference" id="cite_ref-globe_3-0"><a href="#cite_note-globe-3">[3]</a></sup>]
# Enter new budget value: $6.5 million
# The_Allnighter approx $1 million
# Enter new budget value: $1 million
# The_Bedroom_Window ['$8.3 million', <sup class="reference" id="cite_ref-curtis_1-0"><a href="#cite_note-curtis-1">[1]</a></sup>, <sup class="reference" id="cite_ref-dino_2-0"><a href="#cite_note-dino-2">[2]</a></sup>]
# Enter new budget value: $8.3 million
# Anguish $2,000,000 (estimated)
# Enter new budget value: $2,000,000
# From_the_Hip ['$9 million', <sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>, ' or $7.5 million', <sup class="reference" id="cite_ref-dino_2-0"><a href="#cite_note-dino-2">[2]</a></sup>]
# Enter new budget value: $9 million
# Crazy_Love redirect. last tried name: Crazy_Love_(1987_film)
# Enter new budget value:
# Akira [<span style="white-space: nowrap"><a href="/wiki/Japanese_yen" title="Japanese yen">¥</a>1.1 billion</span>, <sup class="reference" id="cite_ref-empire_1-0"><a href="#cite_note-empire-1">[1]</a></sup>, ' (', <span style="white-space: nowrap">$9 million</span>, ')', <sup class="reference" id="cite_ref-currency_2-0"><a href="#cite_note-currency-2">[2]</a></sup>]
# Enter new budget value: $9 million
# The_Big_Blue [<a href="/wiki/French_franc" title="French franc">FRF</a>, ' 80 million', <sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>, <br/>, '(', <i>est.</i>, ' ', <a href="/wiki/United_States_dollar" title="United States dollar">USD$</a>, '13.5 million)']
# Enter new budget value: $13.5 million
# Messenger_of_Death unknown
# Enter new budget value:
# Salome's_Last_Dance ['$800,000', <sup class="reference" id="cite_ref-Ireland_1-0"><a href="#cite_note-Ireland-1">[1]</a></sup>, ' or $1.4 million', <sup class="reference" id="cite_ref-irish_2-0"><a href="#cite_note-irish-2">[2]</a></sup>, ' ', <sup class="reference" id="cite_ref-star_3-0"><a href="#cite_note-star-3">[3]</a></sup>]
# Enter new budget value: $800,000
# The_Deceivers ['$5-6 million', <sup class="reference" id="cite_ref-NYTimes_1-0"><a href="#cite_note-NYTimes-1">[1]</a></sup>, <sup class="reference" id="cite_ref-LATimes_2-0"><a href="#cite_note-LATimes-2">[2]</a></sup>]
# Enter new budget value: $5 million
# Field_of_Dreams ['$15 million', <sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>, <sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>]
# Enter new budget value: $15 million
# The_War_of_the_Roses $26 million
# Enter new budget value: $26 million
# Blue_Steel redirect. last tried name: Blue_Steel_(1989_film)
# Enter new budget value:
# Great_Balls_of_Fire! $16-18 million
# Enter new budget value: $17 million
# Scandal $3 million
# Enter new budget value: $3 million
# Kinjite:_Forbidden_Subjects Unknown
# Enter new budget value:
# Dead_Bang $14.5–$15 million
# Enter new budget value: $14.5 million
# Jesus_of_Montreal ['French', <br/>, 'English']
# Enter new budget value: $4.2 million
# Wired ['$13 million', <sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>, <sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>]
# Enter new budget value: $13 million
# Lord_of_the_Flies ['$9 million', <sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>, <sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>]
# Enter new budget value: $9 million
# La_Femme_Nikita 39 million F
# Enter new budget value:
# Revenge ['$20 million', <sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (October 2014)">citation needed</span></a></i>]</sup>]
# Enter new budget value: $20 million
# The_Field IR£5 million
# Enter new budget value:
# Narrow_Margin $15–20 million
# Enter new budget value: $17.5 million
# Madhouse Unknown
# Enter new budget value:
# The_Commitments ['$12–15 million', <sup class="reference" id="cite_ref-AFINotes_1-3"><a href="#cite_note-AFINotes-1">[1]</a></sup>, <sup class="reference" id="cite_ref-IrishSoul_4-0"><a href="#cite_note-IrishSoul-4">[4]</a></sup>, <sup class="reference" id="cite_ref-ScreeningIreland_5-0"><a href="#cite_note-ScreeningIreland-5">[5]</a></sup>, <sup class="reference" id="cite_ref-Surprise_6-0"><a href="#cite_note-Surprise-6">[6]</a></sup>]
# Enter new budget value: $13.5 million
# Europa <div class="plainlist"><ul><li style="white-space: nowrap"><a href="/wiki/Danish_krone" title="Danish krone">DKK</a> 28 million</li><li style="white-space: nowrap">(<a href="/wiki/United_States_dollar" title="United States dollar">US$</a>4 million)</li></ul></div>
# Enter new budget value: $4 million
# The_Adjuster CAD 1,500,000 (estimated)
# Enter new budget value: $1,139,021
# Beethoven ['$18 million', <sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (October 2018)">citation needed</span></a></i>]</sup>]
# Enter new budget value: $18 million
# The_Crying_Game [<a href="/wiki/Pound_sterling" title="Pound sterling">£</a>, '2.3 million']
# Enter new budget value: £2.3 million
# Man_Bites_Dog [<a href="/wiki/Belgian_franc" title="Belgian franc">BEF</a>, '1 million ', <span style="font-size:85%;">(<a href="/wiki/United_States_dollar" title="United States dollar">USD$</a>33,000)</span>]
# Enter new budget value: $33,000
# Strictly_Ballroom AUD 3 million
# Enter new budget value: AU$3 million
# Aces:_Iron_Eagle_III $10-12 million
# Enter new budget value: $11 million
# Brain_Donors Unknown
# Enter new budget value:
# The_Best_Intentions [<a href="/wiki/Swedish_krona" title="Swedish krona">kr</a>, ' 67 million', <sup class="reference" id="cite_ref-Elley_3-0"><a href="#cite_note-Elley-3">[3]</a></sup>]
# Enter new budget value: $7,128,872
# My_Life $15-20 million
# Enter new budget value: $17.5 million
# The_Advocate redirect. last tried name: The_Advocate_(1993_film)
# Enter new budget value:
# Bad_Girls $25-35 million
# Enter new budget value: $30 million
# Chasers ['$15 million', <sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (April 2018)">citation needed</span></a></i>]</sup>]
# Enter new budget value: $15 million
# Ashes_of_Time Hong Kong
# Enter new budget value: US$1,912,490
# Speechless ['$30 million', <sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (August 2019)">citation needed</span></a></i>]</sup>]
# Enter new budget value: $30 million
# The_Horseman_on_the_Roof $26,8 million
# Enter new budget value: $26.8 million
# Pusher 6.000.000 DKK
# Enter new budget value: $892,764
# House_Arrest ['$5 million', <sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (May 2014)">citation needed</span></a></i>]</sup>]
# Enter new budget value: $5 million
# Moll_Flanders [<a href="/wiki/United_States_dollar" title="United States dollar">US$</a>, '16 million']
# Enter new budget value: $16 million
# Princess_Mononoke Japan
# Enter new budget value: $23.5 million
# Perfect_Blue [<span style="white-space: nowrap">¥90 million</span>, <sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>, ' (', <span style="white-space: nowrap">$6,875,200</span>, ')', <sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>]
# Enter new budget value: $6,875,200
# Open_Your_Eyes ESP 370 million
# Enter new budget value:
# The_Castle redirect. last tried name: The_Castle_(1997_film)
# Enter new budget value:
# Fireworks redirect. last tried name: Fireworks_(1997_film)
# Enter new budget value: $2.3 million
# Murder_at_1600 $40-50 million
# Enter new budget value: $45 million
# Lock,_Stock_and_Two_Smoking_Barrels <div class="plainlist"> <ul><li><a href="/wiki/Pound_sterling" title="Pound sterling">£</a>800,000</li> <li>(<a href="/wiki/United_States_dollar" title="United States dollar">$</a>1.35 million)</li></ul> </div>
# Enter new budget value: $1.35 million
# Show_Me_Love [<a href="/wiki/Swedish_krona" title="Swedish krona">SEK</a>, ' 9,000,000']
# Enter new budget value: $957,609
# Taxi $8.7 million
# Enter new budget value: $8.7 million
# Kuch_Kuch_Hota_Hai [<span style="white-space: nowrap">₹</span>, '140 million', <sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>]
# Enter new budget value: $1,980,492
# Rudolph_the_Red-Nosed_Reindeer redirect. last tried name: Rudolph_the_Red-Nosed_Reindeer_(1998_film)
# Enter new budget value: $10 million
# All_About_My_Mother ['600 million ', <a href="/wiki/Spanish_peseta" title="Spanish peseta">pesetas</a>, ' ($4,989,091)']
# Enter new budget value: $4,989,091
# East_Is_East £1.9 million
# Enter new budget value: £1.9 million
# Code_Unknown [<a href="/wiki/French_language" title="French language">French</a>, <br/>, <a class="mw-redirect" href="/wiki/Maninka" title="Maninka">Maninka</a>, <br/>, <a href="/wiki/Romanian_language" title="Romanian language">Romanian</a>, <br/>, <a href="/wiki/German_language" title="German language">German</a>, <br/>, 'English', <br/>, <a href="/wiki/Arabic" title="Arabic">Arabic</a>, <br/>, <a href="/wiki/French_Sign_Language" title="French Sign Language">French Sign Language</a>]
# Enter new budget value: $7.3 million
# Together ['17,000,000 ', <a href="/wiki/Swedish_krona" title="Swedish krona">SEK</a>]
# Enter new budget value: $1,808,818
# Hey_Ram [<span class="nowrap"><span style="white-space: nowrap">₹</span>6 crore</span>, ' (equivalent to ', <span style="white-space: nowrap">₹</span>, '19\xa0crore or US$2.7\xa0million in 2018)', <sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>]
# Enter new budget value:
# Kaho_Naa..._Pyaar_Hai [<abbr title="estimation">est.</abbr>, ' ', <span style="white-space: nowrap">₹10 <a href="/wiki/Crore" title="Crore">crore</a></span>, <sup class="reference" id="cite_ref-boi_1-0"><a href="#cite_note-boi-1">[1]</a></sup>]
# Enter new budget value:
# Devils_on_the_Doorstep [<a class="mw-redirect" href="/wiki/US_dollar" title="US dollar">US$</a>, '3.9 million', <sup class="reference" id="cite_ref-budget1_1-0"><a href="#cite_note-budget1-1">[1]</a></sup>, <br/>, 'US$2.6 million', <sup class="reference" id="cite_ref-budget2_2-0"><a href="#cite_note-budget2-2">[2]</a></sup>]
# Enter new budget value: US$2.6 million
# The_Claim $20,000,000 (estimated)
# Enter new budget value: $20,000,000
# Kabhi_Khushi_Kabhie_Gham... <span style="white-space: nowrap">₹400 million</span>
# Enter new budget value:
# Dil_Chahta_Hai [<span style="white-space: nowrap">₹</span>, '140 million', <sup class="reference" id="cite_ref-Budget_and_BO_1-0"><a href="#cite_note-Budget_and_BO-1">[1]</a></sup>]
# Enter new budget value:
# Invincible redirect. last tried name: Invincible_(2001_film)
# Enter new budget value:
# Atanarjuat:_The_Fast_Runner [<a href="/wiki/Canadian_dollar" title="Canadian dollar">CA$</a>, '1,960,000 (est.)']
# Enter new budget value: $1,488,321
# Irreversible redirect. last tried name: Irreversible_(2002_film)
# Enter new budget value: €4.6 million
# Bend_It_Like_Beckham [<a href="/wiki/United_States_dollar" title="United States dollar">$</a>, '6\xa0million (', <a href="/wiki/Pound_sterling" title="Pound sterling">£</a>, '3.7\xa0million)']
# Enter new budget value: $6 million
# Russian_Ark ~$2,500,000
# Enter new budget value: $2,500,000
# Devdas redirect. last tried name: Devdas_(2002_film)
# Enter new budget value:
# 8_Women ['€8.5 million', <sup class="reference" id="cite_ref-jpbo_2-0"><a href="#cite_note-jpbo-2">[2]</a></sup>, <br/>, '($7.5 million)']
# Enter new budget value: €8.5 million
# The_Eye ['Hong Kong', <br/>, 'Singapore', <sup class="reference" id="cite_ref-hkarchive_1-0"><a href="#cite_note-hkarchive-1">[1]</a></sup>]
# Enter new budget value:
# High_Tension France
# Enter new budget value: $2.5 million
# The_Return below US$500,000
# Enter new budget value: US$500,000
# Chasing_Papi $9,000,000 USD
# Enter new budget value: $9,000,000
# Young_Adam ['£4 million', <sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>, <sup class="reference" id="cite_ref-Mojo_2-0"><a href="#cite_note-Mojo-2">[2]</a></sup>, <br/>, '($6.4 million)']
# Enter new budget value: £4 million
# Kal_Ho_Naa_Ho [<a href="/wiki/Indian_rupee_sign" title="Indian rupee sign"><span style="white-space: nowrap">₹</span></a>, '280\xa0million.', <sup class="reference" id="cite_ref-Kal_Ho_Naa_Ho_BOI_1-1"><a href="#cite_note-Kal_Ho_Naa_Ho_BOI-1">[1]</a></sup>, <sup class="reference" id="cite_ref-exchange2003_3-0"><a href="#cite_note-exchange2003-3">[a]</a></sup>]
# Enter new budget value:
# Time_of_the_Wolf ['€8.82 million', <sup class="reference" id="cite_ref-jpbo_2-0"><a href="#cite_note-jpbo-2">[2]</a></sup>, <br/>, '($10 million)']
# Enter new budget value: $10 million
# Undead [<a class="mw-redirect" href="/wiki/AUD" title="AUD">A$</a>, '1 million', <sup class="reference" id="cite_ref-numbers_1-0"><a href="#cite_note-numbers-1">[1]</a></sup>, <br/>, '(US$0.75 million)']
# Enter new budget value: US$0.75 million
# The_Barbarian_Invasions ['French', <br/>, 'English']
# Enter new budget value: US$5 million
# Koi..._Mil_Gaya [<span style="white-space: nowrap">₹</span>, '30 crore', <sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>]
# Enter new budget value:
# Pride_and_Prejudice redirect. last tried name: Pride_and_Prejudice_(2003_film)
# Enter new budget value: $350,000
# Downfall ['€13.5 million', <sup class="reference" id="cite_ref-Spiegel_6-0"><a href="#cite_note-Spiegel-6">[6]</a></sup>, ' (approx. $15 million)']
# Enter new budget value: $15 million
# 9_Songs £1 million
# Enter new budget value: £1 million
# The_Motorcycle_Diaries N/A
# Enter new budget value:
# House_of_Flying_Daggers <div class="plainlist"> <ul><li>China</li> <li>Hong Kong</li></ul> </div>
# Enter new budget value: $12 million
# My_Summer_of_Love ['£1 million', <sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (March 2010)">citation needed</span></a></i>]</sup>]
# Enter new budget value: £1 million
# Ghost_in_the_Shell_2:_Innocence [<a class="mw-redirect" href="/wiki/USD" title="USD">$</a>, '20 million', <sup class="reference" id="cite_ref-www.nt2099.com_2-0"><a href="#cite_note-www.nt2099.com-2">[2]</a></sup>]
# Enter new budget value: $20 million
# Black_Friday redirect. last tried name: Black_Friday_(2004_film)
# Enter new budget value: US$940,000
# As_It_Is_in_Heaven [<a href="/wiki/Swedish_krona" title="Swedish krona">SEK</a>, ' 25,000,000 ≈  ', <br/>, ' US$3,700,000']
# Enter new budget value: US$3,700,000
# Swades [<span class="nowrap"><span style="white-space: nowrap">₹</span>21 crore</span>, ' (US$3.0\xa0million)', <sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>]
# Enter new budget value: US$3 million
# Revolver [<a class="mw-redirect" href="/wiki/British_pound" title="British pound">£</a>, '14', <sup class="reference" id="cite_ref-cm_1-0"><a href="#cite_note-cm-1">[1]</a></sup>, ' / ', <a href="/wiki/Euro" title="Euro">€</a>, '20', <sup class="reference" id="cite_ref-jpb_2-0"><a href="#cite_note-jpb-2">[2]</a></sup>, ' / ', <a class="mw-redirect" href="/wiki/US_dollar" title="US dollar">$</a>, '27 million', <sup class="reference" id="cite_ref-cm_1-1"><a href="#cite_note-cm-1">[1]</a></sup>]
# Enter new budget value: $27 million
# Lady_Vengeance South Korea
# Enter new budget value: $4.5 million
# London redirect. last tried name: London_(2005_film)
# Enter new budget value:
# Idiocracy $2–4 million
# Enter new budget value: $3 million
# The_Host South Korea
# Enter new budget value: US$11 million
# Tenacious_D_in_The_Pick_of_Destiny ['$19-20 million', <sup class="reference" id="cite_ref-nyt_1-0"><a href="#cite_note-nyt-1">[1]</a></sup>, <sup class="reference" id="cite_ref-mojo_2-0"><a href="#cite_note-mojo-2">[2]</a></sup>]
# Enter new budget value: $19.5 million
# Rang_De_Basanti [<span style="white-space: nowrap">₹</span>, '280', <span class="nowrap"> </span>, 'million', <sup class="reference" id="cite_ref-boxofficeindia.com_1-0"><a href="#cite_note-boxofficeindia.com-1">[1]</a></sup>]
# Enter new budget value:
# The_Wind_That_Shakes_the_Barley ['€6.5 million', <sup class="reference" id="cite_ref-element_2-4"><a href="#cite_note-element-2">[2]</a></sup>, <sup class="reference" id="cite_ref-numbers_3-0"><a href="#cite_note-numbers-3">[3]</a></sup>, <br/>, '($8.3 million)']
# Enter new budget value: $8.3 million
# Taxidermia [<a href="/wiki/Hungarian_forint" title="Hungarian forint">HUF</a>, ' 500 million', <sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>, <br/>, '(', <span style="white-space: nowrap">US$</span>, '2.4 million)']
# Enter new budget value: $2.4 million
# Akeelah_and_the_Bee ['$6–8 million', <sup class="reference" id="cite_ref-ppgaz_4-0"><a href="#cite_note-ppgaz-4">[3]</a></sup>, <sup class="reference" id="cite_ref-box_5-0"><a href="#cite_note-box-5">[4]</a></sup>]
# Enter new budget value: $7 million
# Hot_Fuzz [<span style="white-space: nowrap">US$</span>, '12–16 million', <sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>, <sup class="reference" id="cite_ref-Numbers_4-0"><a href="#cite_note-Numbers-4">[4]</a></sup>]
# Enter new budget value: $14 million
# The_Diving_Bell_and_the_Butterfly $12.8 million
# Enter new budget value: $12.8 million
# Son_of_Rambow [<a href="/wiki/Pound_sterling" title="Pound sterling">£</a>, '4.5 million', <sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>]
# Enter new budget value: £4.5 million
# The_Visitor redirect. last tried name: The_Visitor_(2007_film)
# Enter new budget value:
# Donkey_Punch [<a href="/wiki/Pound_sterling" title="Pound sterling">£</a>, '1 million', <sup class="reference" id="cite_ref-washingtoncitypaperinterview_2-0"><a href="#cite_note-washingtoncitypaperinterview-2">[2]</a></sup>, <sup class="reference" id="cite_ref-eyeforfilminterview_3-0"><a href="#cite_note-eyeforfilminterview-3">[3]</a></sup>]
# Enter new budget value: £1 million
# 3_Idiots [<span style="white-space: nowrap">₹</span>, '55 ', <a href="/wiki/Crore" title="Crore">crore</a>, <sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>, <sup class="reference" id="cite_ref-exchange_3-0"><a href="#cite_note-exchange-3">[3]</a></sup>]
# Enter new budget value:
# An_Education $7.5 million
# Enter new budget value: $7.5 million
# Spread ['$4,789,700', <sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (August 2015)">citation needed</span></a></i>]</sup>]
# Enter new budget value: $4,789,700
# About_Elly $1،350،000
# Enter new budget value: $1350000
# The_White_Ribbon [<span style="white-space: nowrap">US$</span>, '18 million', <sup class="reference" id="cite_ref-mojo_3-0"><a href="#cite_note-mojo-3">[3]</a></sup>]
# Enter new budget value: $18 million
# Nowhere_Boy [<a href="/wiki/Pound_sterling" title="Pound sterling">₤</a>, '1.2 million', <sup class="reference" id="cite_ref-grant-bbc_3-0"><a href="#cite_note-grant-bbc-3">[3]</a></sup>, <sup class="reference" id="cite_ref-uk-film-council-funding_4-0"><a href="#cite_note-uk-film-council-funding-4">[4]</a></sup>]
# Enter new budget value: £1.2 million
# Mystery_Team < $1 million
# Enter new budget value: $1 million
# Arthur_and_the_Revenge_of_Maltazard [<a href="/wiki/Euro" title="Euro">€</a>, '65 million', <br/>, '(', <a class="mw-redirect" href="/wiki/USD" title="USD">$</a>, '90 million)', <br/>, <small>(shared with <b>Arthur 3</b>)</small>]
# Enter new budget value:
# I_Saw_the_Devil South Korea
# Enter new budget value: US$6 million
# Frozen redirect. last tried name: Frozen_(2010_film)
# Enter new budget value:
# The_Way N/A
# Enter new budget value:
# Trollhunter ['NOK 19 million', <br/>, <span style="font-size:85%;">($3.5 million)</span>]
# Enter new budget value: $3.5 million
# Tamara_Drewe £6–8 million
# Enter new budget value: £7 million
# Ip_Man_2 Hong Kong
# Enter new budget value: US$12,902,809
# Heartbeats [<a href="/wiki/Canadian_dollar" title="Canadian dollar">CAD$</a>, '600,000 ', <span style="font-size:85%;">(approx. <a href="/wiki/United_States_dollar" title="United States dollar">USD$</a>594,695)</span>]
# Enter new budget value: $594,695
# Easy_Money [<a href="/wiki/Swedish_krona" title="Swedish krona">SEK</a>, ' 30 million', <sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>]
# Enter new budget value: $3,192,032
# Elite_Squad:_The_Enemy_Within [<a class="mw-redirect" href="/wiki/BRL" title="BRL">R$</a>, ' 16 million', <sup class="reference" id="cite_ref-Globo2_1-0"><a href="#cite_note-Globo2-1">[1]</a></sup>, <br/>, <small>(<a class="mw-redirect" href="/wiki/USD" title="USD">US$</a> 9,509,65)</small>]
# Enter new budget value:
# The_Trip redirect. last tried name: The_Trip_(2010_film)
# Enter new budget value:
# In_a_Better_World ['DKK30 million (US$5.5 million', <sup class="reference" id="cite_ref-BOM_2-0"><a href="#cite_note-BOM-2">[2]</a></sup>, ')']
# Enter new budget value: US$5.5 million
# Guzaarish <span style="white-space: nowrap"><a href="/wiki/Indian_rupee" title="Indian rupee">₹</a>500 million</span>
# Enter new budget value:
# The_Intouchables [<a href="/wiki/Euro" title="Euro">€</a>, '9.5 million', <br/>, '($10.8 million)']
# Enter new budget value: $10.8 million
# Headhunters [<a class="mw-redirect" href="/wiki/US_Dollar" title="US Dollar">USD</a>, ' 3,636,887 ', <sup class="reference" id="cite_ref-dagbladet_1-0"><a href="#cite_note-dagbladet-1">[1]</a></sup>]
# Enter new budget value: $3,636,887
# Weekend [<a class="mw-redirect" href="/wiki/British_pound" title="British pound">£</a>, '120,000']
# Enter new budget value: £120,000
# Zindagi_Na_Milegi_Dobara [<span class="nowrap"><span style="white-space: nowrap">₹</span>550 million</span>, ' (US$8.0\xa0million)', <sup class="reference" id="cite_ref-znmdbudget_2-0"><a href="#cite_note-znmdbudget-2">[2]</a></sup>]
# Enter new budget value: US$8.0 million
# The_Hunter redirect. last tried name: The_Hunter_(2011_film)
# Enter new budget value:
# Rust_and_Bone ['€15.4 million', <br/>, '(', <a href="/wiki/United_States_dollar" title="United States dollar">$</a>, '20 million)']
# Enter new budget value: $20 million
# Byzantium [<a href="/wiki/Euro" title="Euro">€</a>, '8 million', <sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup>]
# Enter new budget value: €8 million
# John_Dies_at_the_End Less than $1 million
# Enter new budget value: $1 million
# The_Sweeney <a href="/wiki/ITV_(TV_network)" title="ITV (TV network)">ITV</a>
# Enter new budget value: £3 million
# Kahaani <span style="white-space: nowrap"><a href="/wiki/Indian_rupee" title="Indian rupee">₹</a>80 million</span>
# Enter new budget value:
# If_I_Were_You redirect. last tried name: If_I_Were_You_(2012_film)
# Enter new budget value:
# Lore [<a href="/wiki/Euro" title="Euro">EUR €</a>, '4.3 million']
# Enter new budget value: €4.3 million
# The_Reluctant_Fundamentalist ['$15\xa0million', <sup class="reference" id="cite_ref-New_York_Times_budget_3-0"><a href="#cite_note-New_York_Times_budget-3">[3]</a></sup>, <sup class="reference" id="cite_ref-film_budget_4-0"><a href="#cite_note-film_budget-4">[4]</a></sup>]
# Enter new budget value: $15 million
# Dracula_3D [<a href="/wiki/Euro" title="Euro">€</a>, '5.6 million', <br/>, '(', <a href="/wiki/United_States_dollar" title="United States dollar">USD$</a>, '7.7 million)']
# Enter new budget value: $7.7 million
# English_Vinglish [<span style="white-space: nowrap">₹26 <a href="/wiki/Crore" title="Crore">crore</a></span>, <sup class="reference" id="cite_ref-BOI_finances_2-0"><a href="#cite_note-BOI_finances-2">[2]</a></sup>, <sup class="noprint Inline-Template noprint noexcerpt Template-Fact" style="white-space:nowrap;">[<i><a class="mw-redirect" href="/wiki/Wikipedia:NOTRS" title="Wikipedia:NOTRS"><span title="BOI includes print and advertising fees, which are never factored into production budgets. (November 2019)">better source needed</span></a></i>]</sup>]
# Enter new budget value:
# A_Hijacking ['DKK 15 million', <sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>, ' (approx. $2.6 million)']
# Enter new budget value: $2.6 million
# Short_Term_12 under $1 million
# Enter new budget value: $1 million
# Europa_Report Less than $10 million
# Enter new budget value: $10 million
# Austenland [<a href="/wiki/Pound_sterling" title="Pound sterling">£</a>, '4.9 million', <br/>, '(', <a href="/wiki/United_States_dollar" title="United States dollar">$</a>, '7.6 million)']
# Enter new budget value: $7.6 million
# In_a_World... Less than $1 million
# Enter new budget value: $1 million
# The_Tale_of_the_Princess_Kaguya Japan
# Enter new budget value: $49 million
# Jimi:_All_Is_by_My_Side ['$5 million', <sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>, <sup class="reference" id="cite_ref-TN_2-0"><a href="#cite_note-TN-2">[2]</a></sup>]
# Enter new budget value: $5 million
# The_Congress ['€8 million', <sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (July 2014)">citation needed</span></a></i>]</sup>]
# Enter new budget value: €8 million
# PK [<span style="white-space: nowrap"><a href="/wiki/Indian_rupee" title="Indian rupee">₹</a></span>, '85', <span class="nowrap"> </span>, 'crore', <sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[a]</a></sup>]
# Enter new budget value:
# Leviathan ['220 million ', <a href="/wiki/Russian_ruble" title="Russian ruble">RUB</a>]
# Enter new budget value:
# '71 [<a href="/wiki/Pound_sterling" title="Pound sterling">£</a>, '8.1 million', <sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>]
# Enter new budget value: £8.1 million
# Two_Days,_One_Night [<a href="/wiki/Euro" title="Euro">€</a>, '7 million']
# Enter new budget value: €7 million
# Big_Game [<a href="/wiki/Euro" title="Euro">€</a>, '8.5 million', <sup class="reference" id="cite_ref-yle_2014_2-0"><a href="#cite_note-yle_2014-2">[2]</a></sup>, <br/>, '(', <a href="/wiki/United_States_dollar" title="United States dollar">$</a>, '10 million)']
# Enter new budget value: $10 million
# In_Order_of_Disappearance [<a href="/wiki/Norwegian_krone" title="Norwegian krone">kr</a>, '30 million', <sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>]
# Enter new budget value: $3,324,015
# The_Tribe [<a class="mw-redirect" href="/wiki/Hryvnia" title="Hryvnia">₴</a>, ' 14 mln.', <sup class="reference" id="cite_ref-VZ_2-0"><a href="#cite_note-VZ-2">[2]</a></sup>, ' ', <small>(<a class="mw-redirect" href="/wiki/USD" title="USD">$</a> 1.5 mln.<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>)</small>]
# Enter new budget value: $1.5 million
# Youth <div class="plainlist"> <ul><li><a href="/wiki/Euro" title="Euro">€</a>12.8 million<sup class="reference" id="cite_ref-jpbo_3-0"><a href="#cite_note-jpbo-3">[3]</a></sup></li> <li>(<a href="/wiki/United_States_dollar" title="United States dollar">$</a>14.4 million)</li></ul> </div>
# Enter new budget value: €12.8 million
# Far_from_the_Madding_Crowd [<a href="/wiki/Pound_sign" title="Pound sign">£</a>, '12 million', <sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>]
# Enter new budget value: £12 million
# Born_to_Be_Blue less than $10 million
# Enter new budget value: $10 million
# The_Handmaiden South Korea
# Enter new budget value: $8.8 million
# Lady_Macbeth [<a class="mw-redirect" href="/wiki/%C2%A3" title="£">£</a>, '500,000', <br/>, '(', <a class="mw-redirect" href="/wiki/USD$" title="USD$">$</a>, '650,000)', <sup class="reference" id="cite_ref-preview_2-0"><a href="#cite_note-preview-2">[2]</a></sup>]
# Enter new budget value: $650,000
# Dangal [<span style="white-space: nowrap"><a href="/wiki/Indian_rupee" title="Indian rupee">₹</a></span>, '70', <span class="nowrap"> </span>, <a href="/wiki/Crore" title="Crore">crore</a>, <sup class="reference" id="cite_ref-budget_3-0"><a href="#cite_note-budget-3">[3]</a></sup>]
# Enter new budget value:
# Hunt_for_the_Wilderpeople [<a href="/wiki/United_States_dollar" title="United States dollar">US$</a>, '2.5 million', <sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>]
# Enter new budget value: $2.5 million
# Toni_Erdmann <div class="plainlist"> <ul><li><a href="/wiki/Euro" title="Euro">€</a>3 million</li> <li>(<a href="/wiki/United_States_dollar" title="United States dollar">USD$</a>3.2 million)</li></ul> </div>
# Enter new budget value: $3.2 million
# The_Wailing South Korea
# Enter new budget value: US$8 million
# Lowriders ['$5 million', <sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>, <sup class="reference" id="cite_ref-budget_3-0"><a href="#cite_note-budget-3">[3]</a></sup>]
# Enter new budget value: $5 million

# %%
#DO NOT RUN AGAIN. THIS WRITES THE MANUALLY INSERTED VALUES INTO A FILE
#Backup the dictFile with the new manually inserted values
with open("manuallyInserted.txt","w",encoding="utf-8") as file:
    for key, value in dictFile.items():
        file.write(key+"==="+str(value).replace("\n"," ")+"\n")

# %%
#Run after fresh start to get the manually fixed budget values
with open("manuallyInserted.txt","r",encoding="utf-8") as file:
    lines = file.readlines()
for line in lines:
    if line=="":
        continue
    split = line.split("===")
    dictFile[split[0]] = split[1].replace("\n","")

# %% [markdown]
# ### Add the newfound values into the set

# %%
for key, value in dictFile.items():
    if type(value)==float:
        data[data["name"] == key.replace("_"," ")] = data[data["name"] == key.replace("_"," ")].replace(to_replace=0.0,value=value)

# %% [markdown]
# ### Encoding labels

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

##strings to numbers
le = LabelEncoder()
le.fit(data['company'])
data['company'] = le.transform(data['company'])

le1 = LabelEncoder()
le1.fit(data['country'])
data['country'] = le1.transform(data['country'])

le2 = LabelEncoder()
le2.fit(data['director'])
data['director'] = le2.transform(data['director'])

le3 = LabelEncoder()
le3.fit(data['genre'])
data['genre'] = le3.transform(data['genre'])

le4 = LabelEncoder()
le4.fit(data['name'])
data['name'] = le4.transform(data['name'])

le5 = LabelEncoder()
le5.fit(data['rating'])
data['rating'] = le5.transform(data['rating'])

le6 = LabelEncoder()
le6.fit(data['star'])
data['star'] = le6.transform(data['star'])

le7 = LabelEncoder()
le7.fit(data['writer'])
data['writer'] = le7.transform(data['writer'])

le8 = LabelEncoder()
le8.fit(data['released'])
data['released'] = le8.transform(data['released'])


data.head(20)
# Out:
#         budget  company  country  director  genre        gross  name  rating  \
# 0   8000000.00      665       54      2192      1  52287414.00  4661       8
# 1   6000000.00     1680       54      1296      4  70136369.00  1821       7
# 2  15000000.00     1680       54      2645      0 179800601.00  6203       6
# 3  18500000.00     2062       54      1066      0  85160248.00   295       8
# 4   9000000.00     2122       54      2123      1  18564613.00  1872       6
# 5   6000000.00     1158       53      1948      6 138530565.00  3903       8
# 6  25000000.00     1160       53      1207      1  12729917.00  2883       6
# 7   6000000.00      768       54       588      6   8551228.00   771       8
# 8   9000000.00     1680       54      1004      4  40471663.00  3964       7
# 9  15000000.00     1854       54       557      6  40456565.00  5306       8
# 10  8800000.00     1827        2      2033      1 174635000.00  1238       7
# 11 16000000.00     2024       53      2292      0   5900000.00  2306       8
# 12  6000000.00     2062       54       612      4   8200000.00  3110       7
# 13 25000000.00     2062       54      1267      0  11100000.00   686       7
# 14 15000000.00      768       54      1792      5   8620929.00  3196       8
# 15 17000000.00     1752       54        28      6   6734844.00    93       8
# 16 10000000.00      768       54      2447      0   7433663.00  3248       8
# 17 25000000.00     1052       54       811      4  38747385.00  3022       7
# 18  2700000.00     1579       54      1845      0   3500000.00  6093       7
# 19 35000000.00     2085       54      2699      0  16295774.00  2413       6
#
#     released  runtime  score  star   votes  writer  year
# 0         39       89   8.10  2454  299174    3716  1986
# 1         27      103   7.80  1605  264740    1970  1986
# 2         23      110   6.90  2345  236909    1852  1986
# 3         33      137   8.40  2192  540152    1629  1986
# 4         36       90   6.90  1139   36636    2549  1986
# 5         75      120   8.10   369  317585    2988  1986
# 6         30      101   7.40   528  102879     977  1986
# 7         51      120   7.80   924  146768     897  1986
# 8          9       96   6.80  1730   60565    1970  1986
# 9         38       96   7.50  1039  129698    1333  1986
# 10        45       97   6.50  1856   79465    2252  1986
# 11        10      116   7.20   424  104860    1408  1986
# 12        14      100   6.80   456   12228     931  1986
# 13        31       99   7.30  1402  101678    1288  1986
# 14        38      120   7.20  2468   54000    3885  1986
# 15         8      117   5.90  1693   31798    1137  1986
# 16        34       98   5.40   684   24881    3716  1986
# 17        65       94   6.90  1984   53327    1516  1986
# 18        60       93   5.90   369   11635    2816  1986
# 19        36      110   4.60  1434   36020    3749  1986

# %% [markdown]
# ### Drop all movies with no budget

# %%
data = data[data["budget"]!=0]

# %% [markdown]
# # Working with the data, predictions, and analysis

# %%
#Splitting into training and test sets
labels = data["gross"]
movie_data = data.drop(["gross"],1)

X_train, X_test, y_train, y_test = train_test_split(movie_data, labels, test_size = 0.3, random_state = 0)

# %%
#Use a RandomForest model and predict the gross values
rf = RandomForestClassifier(criterion="gini",n_estimators=80, max_depth=160).fit(X_train, y_train)
predictions = rf.predict(X_test)
pList = predictions.tolist()

# %%
#Making a dataframe for reading the prediction results
accuracyResults = pd.DataFrame(columns=["name","realGross","predictedGross","difference"])
for i in range(len(pList)):
    row = X_test.iloc[i]
    label = y_test.iloc[i]
    accuracyResults = accuracyResults.append({"name":row["name"],"realGross":label,"predictedGross":pList[i],"difference":abs(label-pList[i])},ignore_index=True)

with open("modelsUsed.txt","a",encoding="utf-8") as f:
    f.write("model==="+str(rf)+"\tmean==="+str(accuracyResults["difference"].mean())+"\n")
accuracyResults["difference"].describe()
# Out:
# count        1392.00
# mean     31601825.68
# std      44874187.82
# min            14.00
# 25%       5047051.50
# 50%      16704726.00
# 75%      39715468.75
# max     457228248.00
# Name: difference, dtype: float64

# %%
#Make labels human readable again
data['company'] = le.inverse_transform(data['company'])
data['country'] = le1.inverse_transform(data['country'])
data['director'] = le2.inverse_transform(data['director'])
data['genre'] = le3.inverse_transform(data['genre'])
data['name'] = le4.inverse_transform(data['name'])
data['rating'] = le5.inverse_transform(data['rating'])
data['star'] = le6.inverse_transform(data['star'])
data['writer'] = le7.inverse_transform(data['writer'])
data['released'] = le8.inverse_transform(data['released'])

data.head()
# Out:
#        budget                                 company country        director  \
# 0  8000000.00           Columbia Pictures Corporation     USA      Rob Reiner
# 1  6000000.00                      Paramount Pictures     USA     John Hughes
# 2 15000000.00                      Paramount Pictures     USA      Tony Scott
# 3 18500000.00  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4  9000000.00                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre        gross                      name rating    released  \
# 0  Adventure  52287414.00               Stand by Me      R  1986-08-22
# 1     Comedy  70136369.00  Ferris Bueller's Day Off  PG-13  1986-06-11
# 2     Action 179800601.00                   Top Gun     PG  1986-05-16
# 3     Action  85160248.00                    Aliens      R  1986-07-18
# 4  Adventure  18564613.00   Flight of the Navigator     PG  1986-08-01
#
#    runtime  score               star   votes         writer  year
# 0       89   8.10        Wil Wheaton  299174   Stephen King  1986
# 1      103   7.80  Matthew Broderick  264740    John Hughes  1986
# 2      110   6.90         Tom Cruise  236909       Jim Cash  1986
# 3      137   8.40   Sigourney Weaver  540152  James Cameron  1986
# 4       90   6.90        Joey Cramer   36636  Mark H. Baker  1986

# %%
#Making a heatmap of all correlations
import seaborn as sns
correlations = data.corr()
plt.figure(figsize=(12, 10))
sns.set(font_scale=1.4)
sns.heatmap(correlations,annot=True)
plt.yticks(rotation=0)
plt.savefig("correlations.png")

# %%
#Turn the values into millions
accuracyResults["realGross"] = accuracyResults["realGross"]/1000000
accuracyResults["predictedGross"] = accuracyResults["predictedGross"]/1000000
accuracyResults["difference"] = accuracyResults["difference"]/1000000
accuracyResults
# Out:
#         name  realGross  predictedGross  difference
# 0     118.00       7.46           43.14       35.68
# 1    2398.00      31.16            0.07       31.08
# 2    3597.00      31.49            0.07       31.42
# 3    3944.00       0.02            0.05        0.03
# 4    4608.00      52.01            0.03       51.98
# 5    2210.00     261.99           58.22      203.77
# 6    4304.00      83.30           52.08       31.22
# 7    4173.00      63.10          121.95       58.85
# 8    6295.00      57.14          101.16       44.02
# 9    6210.00      58.88           67.63        8.75
# 10   1704.00       0.11           15.03       14.92
# 11   4179.00      30.05           43.25       13.20
# 12   1902.00      17.86           10.40        7.46
# 13   2403.00      46.81            4.69       42.12
# 14   4612.00       9.70            4.94        4.76
# 15     17.00      52.85           71.90       19.04
# 16   3189.00      34.58           32.94        1.64
# 17   1792.00     238.68          209.84       28.84
# 18   5278.00      75.79           26.84       48.95
# 19   2037.00       6.22            4.06        2.16
# 20   2254.00       5.00           13.05        8.05
# 21   4659.00       3.30            3.53        0.22
# 22   2289.00      67.29           57.76        9.53
# 23   2721.00     652.27          195.04      457.23
# 24   3662.00     116.09           81.26       34.83
# 25   1288.00       4.53            1.79        2.74
# 26   4008.00      17.84           24.79        6.95
# 27   1001.00       0.25            0.14        0.11
# 28   1984.00      51.86          120.06       68.20
# 29    861.00      70.77           25.48       45.29
# ...      ...        ...             ...         ...
# 1362 2956.00      82.39           16.17       66.22
# 1363   44.00      45.06           76.81       31.74
# 1364 6224.00      21.45           10.44       11.01
# 1365 2381.00      19.28           26.39        7.10
# 1366 1521.00       1.96           13.61       11.65
# 1367 5172.00      17.88           14.25        3.63
# 1368 4547.00       8.35           32.39       24.04
# 1369 1361.00      73.65           58.06       15.59
# 1370  572.00     206.85          188.02       18.83
# 1371 4206.00     532.18          486.30       45.88
# 1372 1767.00       1.66            2.71        1.05
# 1373 3766.00       7.29           14.00        6.71
# 1374 6729.00       2.55           39.25       36.70
# 1375 1447.00     150.95          117.72       33.22
# 1376 4171.00     176.76          176.24        0.52
# 1377  613.00       5.54           25.01       19.48
# 1378 5580.00     111.54           27.10       84.44
# 1379 1238.00     174.63            6.91      167.73
# 1380 3196.00       8.62            1.11        7.51
# 1381  477.00      19.55           15.13        4.42
# 1382 5072.00     227.47          121.66      105.81
# 1383 1872.00      18.56           17.22        1.35
# 1384 1944.00      17.13           20.15        3.02
# 1385 5432.00      41.68           75.07       33.40
# 1386 5603.00       8.57           10.16        1.59
# 1387 1037.00       1.73           38.32       36.59
# 1388 6477.00      22.47            0.58       21.89
# 1389  984.00      18.67           60.86       42.19
# 1390 1477.00      41.91           36.95        4.96
# 1391 4411.00      10.07            0.78        9.28
#
# [1392 rows x 4 columns]

# %%
#Showing the ratio between real and predicted gross values
plt.scatter(accuracyResults["realGross"],accuracyResults["predictedGross"],color="firebrick")
plt.xlabel("Real gross (million)")
plt.ylabel("Predicted gross (million)")
plt.title("Ratio between actual and predicted gross")
plt.plot([0,900],[0,400],"k-")
plt.savefig("ratio.png")

# %%
#Find different plots for different decades
means = {}
stdevs = {}
feature = "genre"
for i in range(1980,2016,10):
    decades = data[(data["year"]>i) & (data["year"]<i+10)]
    plt.title(str(i)[-2:]+"'s")
    plt.xlabel("Genre")
    plt.ylabel("Gross")
    plt.xticks(rotation="vertical")
    plt.bar(decades[feature].value_counts().keys(),decades.groupby(feature)["gross"].mean())
    plt.savefig(str(i)[-2:]+"'s.png")
    plt.show()

# %%
from scipy import stats

#the biggest correlations between gross and a feature
#budget
pearson_coef, p_value = stats.pearsonr(data["budget"], data["gross"])
print("Pearson Correlation Coefficient: ", pearson_coef)
# Out:
# Pearson Correlation Coefficient:  0.7121955325421071

# %%
#votes
pearson_coef, p_value = stats.pearsonr(data["votes"], data["gross"])
print("Pearson Correlation Coefficient: ", pearson_coef)
# Out:
# Pearson Correlation Coefficient:  0.6624571618429045

# %%
#correlation between gross and other features
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(data = data, x_vars = ["budget","company","country","director","genre","name"], y_vars = ["gross"])
g = sns.pairplot(data = data, x_vars = ["rating","released","runtime","score","star","votes"], y_vars = ["gross"])
g = sns.pairplot(data = data, x_vars = ["writer","year"], y_vars = ["gross"])

# %%
sort = data.sort_values(by = ["gross"], ascending=[False])

# %%
#finding the 100 movies with biggest gross
biggest_values = sort.head(100)
biggest_values.head()
# Out:
#            budget                                 company country  \
# 6380 245000000.00                               Lucasfilm     USA
# 5061 237000000.00  Twentieth Century Fox Film Corporation      UK
# 2420 200000000.00  Twentieth Century Fox Film Corporation     USA
# 6391 150000000.00                      Universal Pictures     USA
# 5723 220000000.00                          Marvel Studios     USA
#
#              director   genre        gross                          name  \
# 6380      J.J. Abrams  Action 936662225.00  Star Wars: The Force Awakens
# 5061    James Cameron  Action 760507625.00                        Avatar
# 2420    James Cameron   Drama 658672302.00                       Titanic
# 6391  Colin Trevorrow  Action 652270625.00                Jurassic World
# 5723      Joss Whedon  Action 623357910.00                  The Avengers
#
#      rating    released  runtime  score               star    votes  \
# 6380  PG-13  2015-12-18      136   8.10       Daisy Ridley   687192
# 5061  PG-13  2009-12-18      162   7.80    Sam Worthington   954412
# 2420  PG-13  1997-12-19      194   7.80  Leonardo DiCaprio   862554
# 6391  PG-13  2015-06-12      124   7.00        Chris Pratt   469200
# 5723  PG-13  2012-05-04      143   8.10  Robert Downey Jr.  1064633
#
#                writer  year
# 6380  Lawrence Kasdan  2015
# 5061    James Cameron  2009
# 2420    James Cameron  1997
# 6391       Rick Jaffa  2015
# 5723      Joss Whedon  2012

# %%
g = sns.pairplot(data = biggest_values, x_vars = ["budget","company","country","director","genre","name"], y_vars = ["gross"])
g = sns.pairplot(data = biggest_values, x_vars = ["rating","released","runtime","score","star","votes"], y_vars = ["gross"])
g = sns.pairplot(data = biggest_values, x_vars = ["writer","year"], y_vars = ["gross"])

# %%
#finding data, where gross is at least twice the budget

best_data = pd.DataFrame(data, columns = ["budget","company","country","director","genre","gross","name","rating","released",
                                          "runtime","score","star","votes","writer","year"])

# for i in range(len(best_data)):
#     if best_data.iloc[i,:].budget == 0.0 or best_data.iloc[i,:].budget == 0:
#         best_data.drop(best_data.index[i])
        
for i in range(len(best_data)):
    if best_data.iloc[i,:].gross/best_data.iloc[i,:].budget < 2:
        best_data.drop(best_data.index[i])
        
best_data.head()
# Out:
#        budget  company  country  director  genre        gross  name  rating  \
# 0  8000000.00      665       54      2192      1  52287414.00  4661       8
# 1  6000000.00     1680       54      1296      4  70136369.00  1821       7
# 2 15000000.00     1680       54      2645      0 179800601.00  6203       6
# 3 18500000.00     2062       54      1066      0  85160248.00   295       8
# 4  9000000.00     2122       54      2123      1  18564613.00  1872       6
#
#    released  runtime  score  star   votes  writer  year
# 0        39       89   8.10  2454  299174    3716  1986
# 1        27      103   7.80  1605  264740    1970  1986
# 2        23      110   6.90  2345  236909    1852  1986
# 3        33      137   8.40  2192  540152    1629  1986
# 4        36       90   6.90  1139   36636    2549  1986

# %%
data = pd.read_csv("movies.csv", encoding='latin-1')

best_data = pd.DataFrame(data, columns = ["budget","company","country","director","genre","gross","name","rating","released",
                                          "runtime","score","star","votes","writer","year"])

for i in range(len(best_data)):
    if best_data.iloc[i,:].gross/best_data.iloc[i,:].budget < 2:
        best_data.drop(best_data.index[i])
# Out:
# C:\Users\Silver\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in double_scalars
#   import sys

# %%
g = sns.pairplot(data = best_data, x_vars = ["budget","company","country","director","genre","name"], y_vars = ["gross"])
g = sns.pairplot(data = best_data, x_vars = ["rating","released","runtime","score","star","votes"], y_vars = ["gross"])
g = sns.pairplot(data = best_data, x_vars = ["writer","year"], y_vars = ["gross"])
